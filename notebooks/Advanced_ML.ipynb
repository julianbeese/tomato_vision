# %% [markdown]
# # Setup

# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np
import re

import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
import torch.nn as nn
import torch.optim as optim

from PIL import Image
from io import BytesIO
from torchvision import transforms
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Sampling DataSet

# %%
# Read the dataset from Hugging Face using Dask
df = dd.read_parquet(
    "hf://datasets/raghavendrad60/vqa_plant-disease-classification-merged-dataset/data/train-*.parquet",
    columns=['class', 'image']
)

# Plants to keep
patterns = ['Tomato', 'Chili', 'Cucumber', 'Strawberry', 'Pepper']
desired_plants = [p.lower() for p in patterns]

# Filter function to include only desired plants
def filter_partition(df):
    df['class'] = df['class'].astype(str).str.strip().str.lower()
    df['plant'] = df['class'].str.extract(r'^([^_]+)')
    return df[df['plant'].isin(desired_plants)]

df = df.map_partitions(filter_partition).persist()

# Function to sample a small number of rows from a partition
def sample_partition(partition, n_per_partition=200):
    return partition.sample(n=min(len(partition), n_per_partition), random_state=np.random.randint(0, 1e6))

# Sample a limited number of rows from each partition
sampled = df.map_partitions(sample_partition, n_per_partition=200)

# Collect the sampled data into memory, then take a final random sample of 50000
sampled_df = sampled.compute()
final_sample = sampled_df.sample(n=min(5000, len(sampled_df)), random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/fsspec/registry.py:249, in get_filesystem_class(protocol)
#     248 try:
# --> 249     register_implementation(protocol, _import_class(bit["class"]))
#     250 except ImportError as e:
#
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/fsspec/registry.py:284, in _import_class(fqp)
#     283 is_s3 = mod == "s3fs"
# --> 284 mod = importlib.import_module(mod)
#     285 if is_s3 and mod.__version__.split(".") < ["0", "5"]:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1142, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'huggingface_hub'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/dask/backends.py:140, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     139 try:
# --> 140     return func(*args, **kwargs)
#     141 except Exception as e:
#
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/dask/dataframe/dask_expr/_collection.py:5372, in read_parquet(path, columns, filters, categories, index, storage_options, dtype_backend, calculate_divisions, ignore_metadata_file, metadata_task_size, split_row_groups, blocksize, aggregate_files, parquet_file_extension, filesystem, engine, arrow_to_pandas, **kwargs)
#    5353     return new_collection(
#    5354         ReadParquetPyarrowFS(
#    5355             path,
#    (...)   5368         )
#    5369     )
#    5371 return new_collection(
# -> 5372     ReadParquetFSSpec(
#    5373         path,
#    5374         columns=_convert_to_list(columns),
#    5375         filters=filters,
#    5376         categories=categories,
#    5377         index=index,
#    5378         storage_options=storage_options,
#    5379         calculate_divisions=calculate_divisions,
#    5380         ignore_metadata_file=ignore_metadata_file,
#    5381         metadata_task_size=metadata_task_size,
#    5382         split_row_groups=split_row_groups,
#    5383         blocksize=blocksize,
#    5384         aggregate_files=aggregate_files,
#    5385         parquet_file_extension=parquet_file_extension,
#    5386         filesystem=filesystem,
#    5387         engine=_set_parquet_engine(engine),
#    5388         kwargs=kwargs,
#    5389         _series=isinstance(columns, str),
#    5390     )
#    5391 )
#
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/dask/_expr.py:844, in SingletonExpr.__new__(cls, _determ_token, *args, **kwargs)
#     843     cls._instances = weakref.WeakValueDictionary()
# --> 844 inst = super().__new__(cls, *args, _determ_token=_determ_token, **kwargs)
#     845 _name = inst._name
#
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/dask/_expr.py:72, in Expr.__new__(cls, _determ_token, *args, **kwargs)
#      70 # This is typically cached. Make sure the cache is populated by calling
#      71 # it once
# ---> 72 inst._name
#      73 return inst
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/functools.py:1001, in cached_property.__get__(self, instance, owner)
#    1000 if val is _NOT_FOUND:
# -> 1001     val = self.func(instance)
#    1002     try:
#
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/dask/dataframe/dask_expr/io/parquet.py:790, in ReadParquet._name(self)
#     788 @cached_property
#     789 def _name(self):
# --> 790     return self._funcname + "-" + self.deterministic_token
#
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/dask/_expr.py:517, in Expr.deterministic_token(self)
#     514 if not self._determ_token:
#     515     # Just tokenize self to fall back on __dask_tokenize__
#     516     # Note how this differs to the implementation of __dask_tokenize__
# --> 517     self._determ_token = self.__dask_tokenize__()
#     518 return self._determ_token
#
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/dask/dataframe/dask_expr/io/parquet.py:784, in ReadParquet.__dask_tokenize__(self)
#     781 if not self._determ_token:
#     782     # TODO: Is there an actual need to overwrite this?
#     783     self._determ_token = _tokenize_deterministic(
# --> 784         funcname(type(self)), self.checksum, *self.operands[:-1]
#     785     )
#     786 return self._determ_token
#
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/dask/dataframe/dask_expr/io/parquet.py:794, in ReadParquet.checksum(self)
#     792 @property
#     793 def checksum(self):
# --> 794     return self._dataset_info["checksum"]
#
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/dask/dataframe/dask_expr/io/parquet.py:1325, in ReadParquetFSSpec._dataset_info(self)
#    1324 # Extract global filesystem and paths
# -> 1325 fs, paths, dataset_options, open_file_options = self.engine.extract_filesystem(
#    1326     self.path,
#    1327     self.filesystem,
#    1328     dataset_options,
#    1329     open_file_options,
#    1330     self.storage_options,
#    1331 )
#    1332 read_options["open_file_options"] = open_file_options
#
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/dask/dataframe/io/parquet/arrow.py:501, in ArrowDatasetEngine.extract_filesystem(cls, urlpath, filesystem, dataset_options, open_file_options, storage_options)
#     500 # Use default file-system initialization
# --> 501 return Engine.extract_filesystem(
#     502     urlpath,
#     503     fs,
#     504     dataset_options,
#     505     open_file_options,
#     506     storage_options,
#     507 )
#
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/dask/dataframe/io/parquet/utils.py:72, in Engine.extract_filesystem(cls, urlpath, filesystem, dataset_options, open_file_options, storage_options)
#      70 if fs in (None, "fsspec"):
#      71     # Use fsspec to infer a filesystem by default
# ---> 72     fs, _, paths = get_fs_token_paths(
#      73         urlpath, mode="rb", storage_options=storage_options
#      74     )
#      75     return fs, paths, dataset_options, open_file_options
#
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/fsspec/core.py:655, in get_fs_token_paths(urlpath, mode, num, name_function, storage_options, protocol, expand)
#     654     storage_options["protocol"] = protocol
# --> 655 chain = _un_chain(urlpath0, storage_options or {})
#     656 inkwargs = {}
#
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/fsspec/core.py:351, in _un_chain(path, kwargs)
#     350 protocol = kwargs.pop("protocol", None) or split_protocol(bit)[0] or "file"
# --> 351 cls = get_filesystem_class(protocol)
#     352 extra_kwargs = cls._get_kwargs_from_urls(bit)
#
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/fsspec/registry.py:251, in get_filesystem_class(protocol)
#     250     except ImportError as e:
# --> 251         raise ImportError(bit.get("err")) from e
#     252 cls = registry[protocol]
#
# ImportError: Install huggingface_hub to access HfFileSystem
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Read the dataset from Hugging Face using Dask
# ----> 2 df = dd.read_parquet(
#       3     "hf://datasets/raghavendrad60/vqa_plant-disease-classification-merged-dataset/data/train-*.parquet",
#       4     columns=['class', 'image']
#       5 )
#       7 # Plants to keep
#       8 patterns = ['Tomato', 'Chili', 'Cucumber', 'Strawberry', 'Pepper']
#
# File ~/Developer/NOVA/tomato_vision/venv/lib/python3.11/site-packages/dask/backends.py:151, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     149     raise e
#     150 else:
# --> 151     raise exc from e
#
# ImportError: An error occurred while calling the read_parquet method registered to the pandas backend.
# Original Message: Install huggingface_hub to access HfFileSystem

# %%
final_sample
# Out:
#                                class  \
# 1314          tomato__bacterial_spot
# 1556  tomato__yellow_leaf_curl_virus
# 1868             strawberry__healthy
# 421              tomato__target_spot
# 1043            pepper_bell__healthy
# ...                              ...
# 226       tomato__septoria_leaf_spot
# 1449          tomato__bacterial_spot
# 1069             tomato__late_blight
# 292              tomato__target_spot
# 483                 chili__leaf curl
#
#                                                   image       plant
# 1314  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      tomato
# 1556  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      tomato
# 1868  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  strawberry
# 421   {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      tomato
# 1043  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      pepper
# ...                                                 ...         ...
# 226   {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      tomato
# 1449  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      tomato
# 1069  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      tomato
# 292   {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      tomato
# 483   {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...       chili
#
# [3655 rows x 3 columns]

# %% [markdown]
# # Training

# %%
# Count samples per class
class_counts = final_sample['class'].value_counts()
print(class_counts)

# Filter out classes with fewer than 2 samples
valid_classes = class_counts[class_counts >= 2].index
final_sample = final_sample[final_sample['class'].isin(valid_classes)]
# Out:
# class
# tomato__late_blight                               382
# tomato__yellow_leaf_curl_virus                    375
# tomato__target_spot                               355
# cucumber__healthy                                 243
# tomato__septoria_leaf_spot                        231
# tomato__leaf_mold                                 213
# strawberry__healthy                               209
# strawberry___leaf_scorch                          200
# tomato__spider_mites_(two_spotted_spider_mite)    200
# tomato__healthy                                   191
# pepper_bell__healthy                              170
# tomato__bacterial_spot                            169
# tomato__mosaic_virus                              134
# tomato__early_blight                              125
# pepper_bell__bacterial_spot                       105
# chili__yellowish                                  100
# chili__leaf curl                                  100
# chili__healthy                                     49
# chili__leaf spot                                   45
# cucumber__diseased                                 42
# chili__whitefly                                    17
# Name: count, dtype: int64

# %%
# Extract actual byte data from the dictionary in the 'image' column
final_sample['image_bytes'] = final_sample['image'].apply(lambda x: eval(x)['bytes'] if isinstance(x, str) else x['bytes'])

# Encode class labels
le = LabelEncoder()
final_sample['label'] = le.fit_transform(final_sample['class'])

# Split
train_df, val_df = train_test_split(final_sample, test_size=0.2, stratify=final_sample['label'], random_state=42)

# Define transform
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# %%
class ByteImageDataset(Dataset):
    def __init__(self, dataframe, transform=None):
        self.df = dataframe
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_bytes = self.df.iloc[idx]['image_bytes']
        image = Image.open(BytesIO(img_bytes)).convert("RGB")
        if self.transform:
            image = self.transform(image)
        label = self.df.iloc[idx]['label']
        return image, label

train_dataset = ByteImageDataset(train_df, transform)
val_dataset = ByteImageDataset(val_df, transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = models.resnet18(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, final_sample['label'].nunique())
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
for epoch in range(5):  # Adjust as needed
    model.train()
    total_loss = 0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
    print(f"Epoch {epoch+1}, Loss: {total_loss:.4f}")

# Evaluation
model.eval()
correct, total = 0, 0
with torch.no_grad():
    for inputs, labels in val_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

print(f"Validation Accuracy: {100 * correct / total:.2f}%")


# saving the Label Encoder as a pickle file
label_encoder_path = 'label_encoder.pkl' # Oder ein anderer Pfad/Dateiname
with open(label_encoder_path, 'wb') as f:
    pickle.dump(le, f)

print(f"LabelEncoder gespeichert unter: {label_encoder_path}")
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 96.7MB/s]

# %% [markdown]
# # Inference (Prediction)

# %%
# Same image preprocessing used during training
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# Inference function
def predict_from_bytes(img_bytes):
    model.eval()
    image = Image.open(BytesIO(img_bytes)).convert("RGB")
    image = transform(image).unsqueeze(0).to(device)  # Add batch dimension
    with torch.no_grad():
        outputs = model(image)
        _, predicted = torch.max(outputs, 1)
        class_index = predicted.item()
        return le.inverse_transform([class_index])[0]  # Return class label

# %%
# Picture input (from file or database)
with open("/content/Tomato_Leaf_Mold_Test3", "rb") as f:
    img_bytes = f.read()

predicted_class = predict_from_bytes(img_bytes)
print("Predicted class:", predicted_class)

# %% [markdown]
# #Save the Model using Pickle

# %%
import pickle

with open('advanced_ml_project_model.pkl', 'wb') as f:
    pickle.dump(model.state_dict(), f)
